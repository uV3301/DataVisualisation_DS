# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['tip'],)

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# C:\Users\uV\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\Users\uV\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-c303f949f24a> in <module>
# ----> 1 sns.attention()
#
# AttributeError: module 'seaborn' has no attribute 'attention'

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'],bins = 40)

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips,kind = 'hex')

# %%
sns.get_dataset_names()
# Out:
# C:\Users\uV\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\Users\uV\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
sns.distplot(flights['passengers'],)

# %%
sns.jointplot('year', 'passengers', data = flights,kind = 'hex',space = 1)

# %%
sns.jointplot('passengers','year', data  = flights,kind = 'kde')

# %%
sns.pairplot(tips,height = 2,kind = 'reg')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot(x='total_bill', y = 'tip',data = tips,)

# %%
sns.pairplot(tips,hue='sex',palette = 'seismic')

# %%
sns.pairplot(tips, hue='sex', palette='rainbow')

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.jointplot('total_bill','tip',tips,kind = 'hex',height = 10,color = 'orange')

# %%
sns.rugplot(flights['passengers'],height =0.6,axis ='y')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
sns.kde()

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(tips,hue = 'smoker',palette = 'twilight')

# %%
sns.kdeplot(tips['total_bill'],color = 'lawngreen')

# %%
import numpy as np

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot('smoker',y='total_bill', data=tips,estimator=np.std)

# %%
 sns.countplot('sex',data=tips,palette = 'rainbow')

# %%
 sns.countplot(x='smoker',data=tips,palette='Blues')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x='time',y='total_bill',data=tips,)

# %%
sns.boxplot(x='sex',y='total_bill',data=tips,palette='rainbow')

# %%
sns.boxplot(x='day',y='total_bill',data=tips,palette='copper')

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker',palette='Purples')

# %%
sns.boxplot(data=tips,palette='Blues')

# %%
sns.violinplot(x='day',y='total_bill',data=tips,palette='rainbow')

# %%
sns.boxplot(x='day',y='total_bill',data=tips,palette='rainbow')

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='smoker',palette='rainbow',split=True)

# %%
sns.boxplot(x='day',y='total_bill',data=tips,palette='rainbow',hue='smoker',notch=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-43528bd022bf> in <module>
# ----> 1 sns.boxplot(x='day',y='total_bill',data=tips,palette='rainbow',hue='smoker',notch=True,split=True)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2235     kwargs.update(dict(whis=whis, notch=notch))
#    2236
# -> 2237     plotter.plot(ax, kwargs)
#    2238     return ax
#    2239
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     547     def plot(self, ax, boxplot_kws):
#     548         """Make the plot."""
# --> 549         self.draw_boxplot(ax, boxplot_kws)
#     550         self.annotate_axes(ax)
#     551         if self.orient == "h":
#
# ...

# %%
sns.stripplot(x='day',y='total_bill',data=tips,size =3.5,hue='sex',split=True)
# Out:
# C:\Users\uV\Anaconda3\lib\site-packages\seaborn\categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')

# %%
sns.violinplot(x='day',y='total_bill',data=tips,palette='Purples')
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')

# %%
sns.factorplot(x='day',y='total_bill',data=tips,hue='smoker',kind='violin',split=True)
# Out:
# C:\Users\uV\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
flights = sns.load_dataset('flights')

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
 flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tk = tips.corr()

# %%
tk
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(data=tk,center=1)

# %%
import numpy as np
np.random.seed(200)

# %%
t = np.random.randint(1,400,20).reshape(4,5)

# %%
sns.heatmap(t,cmap='copper')

# %%
t
# Out:
# array([[  7, 256, 197, 193, 346],
#        [179, 376,  98, 217, 136],
#        [186,  98, 152, 390, 169],
#        [283, 194, 354,  82, 328]])

# %%
tk
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tk,cmap='coolwarm')

# %%
flights.pivot_table(index='month',columns='year',values='passenger')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-156-ca3a95ae7cd8> in <module>
# ----> 1 flights.pivot_table(index='month',columns='year',values='passenger')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    5757                            aggfunc=aggfunc, fill_value=fill_value,
#    5758                            margins=margins, dropna=dropna,
# -> 5759                            margins_name=margins_name)
#    5760
#    5761     def stack(self, level=-1, dropna=True):
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      56         for i in values:
#      57             if i not in data:
# ---> 58                 raise KeyError(i)
#      59
# ...

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
 flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
 k = flights.pivot_table(index='month',columns='year',values='passengers')

# %%
k.max()
# Out:
# year
# 1949    148
# 1950    170
# 1951    199
# 1952    242
# 1953    272
# 1954    302
# 1955    364
# 1956    413
# 1957    467
# 1958    505
# 1959    559
# 1960    622
# dtype: int64

# %%
sns.heatmap(k,cmap='magma',linecolor='white',linewidths='0.4')

# %%
sigure = sns.heatmap(k,cmap='coolwarm',linecolor='black',linewidths='1')

# %%
sigure

# %%
sig = sigure.figure

# %%
sig.savefig('flights_modelPresentation.png',dpi=300)

# %%
sigure.figure

# %%
k
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.clustermap(k)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tk = tips.pivot_table(index='day',columns='sex',values='total_bill')

# %%
tk
# Out:
# sex        Male     Female
# day
# Thur  18.714667  16.715312
# Fri   19.857000  14.145556
# Sat   20.802542  19.680357
# Sun   21.887241  19.872222

# %%
sns.heatmap(tk,cmap='coolwarm')

# %%
sns.clustermap(tk)

# %%
sns.clustermap(k,cmap='coolwarm',standard_scale=1)

# %%
iris = sns.load_dataset('iris')

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species')

# %%
grid = sns.PairGrid(iris)

# %%
import matplotlib.pyplot as plt

# %%
grid.map(plt.scatter)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-223-d89626cc9eeb> in <module>
# ----> 1 grid.map(plt.scatter)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, **kwargs)
#    1331
#    1332                     ax = self.axes[i, j]
# -> 1333                     plt.sca(ax)
#    1334
#    1335                     # Insert the other hue aesthetics if appropriate
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in sca(ax)
#     912             m.canvas.figure.sca(ax)
#     913             return
# --> 914     raise ValueError("Axes instance argument was not found in a figure")
#     915
#     916
#
# ValueError: Axes instance argument was not found in a figure

# %%
grid

# %%
grid.figu
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-225-498d5447339e> in <module>
# ----> 1 grid.figure
#
# AttributeError: 'PairGrid' object has no attribute 'figure'

# %%
sns.pairplot(iris)

# %%
sns.PairGrid(iris)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)

# %%
t
# Out:
# array([[  7, 256, 197, 193, 346],
#        [179, 376,  98, 217, 136],
#        [186,  98, 152, 390, 169],
#        [283, 194, 354,  82, 328]])

# %%
t = sns.PairGrid(iris)
t.map_upper(sns.scatterplot)
t.map_diag(sns.distplot)
t.map_lower(sns.kdeplot)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
q = sns.FacetGrid(data=tips,row='smoker',col='time')
q.map(sns.distplot,'tip')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,paleetex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['v','s'],)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex')

# %%
sns.set_style('ticks')
sns.countplot('sex',data=tips,palette='magma')

# %%
plt.figure(figsize=(10,8))
sns.countplot('sex',data=tips)

# %%
sns.lmplot(x='tip',y='total_bill',data=tips,size=10,aspect=2)
# Out:
# C:\Users\uV\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_context('notebook',font_scale=2)
sns.countplot(x='sex',data=tips,palette='coolwarm')

# %%
OrderedDict()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-308-9136f3b9b1d8> in <module>
# ----> 1 OrderedDict()
#
# NameError: name 'OrderedDict' is not defined

# %%
colormap = plt.cm.get_cmap

# %%
list(colormap)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-316-c02ba8c6629d> in <module>
# ----> 1 list(colormap)
#
# TypeError: 'function' object is not iterable

# %%
t

# %%
tk
# Out:
# sex        Male     Female
# day
# Thur  18.714667  16.715312
# Fri   19.857000  14.145556
# Sat   20.802542  19.680357
# Sun   21.887241  19.872222

# %%
sns.set_context(font_scale=1)
sns.lmplot(x='tip',y='total_bill',data=tips,hue='sex',palette='hsv')

# %%
sns.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-338-6e26d1f0669b> in <module>
# ----> 1 list(sns.palettes)
#
# TypeError: 'module' object is not iterable

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(10,4))
t = sns.FacetGrid(data=tips,col='sex',row='smoker')
t = t.map(sns.distplot,'total_bill')

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(data = tips,col ='sex',row = 'smoker')
g = g.map(sns.distplot,'total_bill')

# %%
g
